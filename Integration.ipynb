# %%
import pandas as pd

# %%
df = pd.read_csv('/content/phishing_site_urls.csv')

# %%
df_1 = df.iloc[:10000,:]
df_2 = df.iloc[10000:,:]
df_2 = df_2.reset_index(drop=True)
df_2 = df_2.replace('bad','1')
df_2 = df_2.replace('good','0')
df_2 = df_2.rename(columns={'URL': 'website url', 'Label': 'label'})

# %%
df_2
# Out:
#                                               website url label
# 0       paypal.com.us-cgi-bin-webscr-cmd.login.5885d80...     1
# 1              www.xn--rhqt00c20if7g.net/1wumt/index.html     1
# 2                                ygirisim.com/aktivering/     1
# 3       horizonsgallery.com/lib/ssl3/bin/_id/www.paypa...     1
# 4       horizonsgallery.com/lib/ssl3/bin/_id/www.paypa...     1
# ...                                                   ...   ...
# 539341                                    23.227.196.215/     1
# 539342                                 apple-checker.org/     1
# 539343                                  apple-iclods.org/     1
# 539344                                 apple-uptoday.org/     1
# 539345                                  apple-search.info     1
#
# [539346 rows x 2 columns]

# %%
df_1
# Out:
#                                                     URL Label
# 0     nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1     www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2     serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3     mail.printakid.com/www.online.americanexpress....   bad
# 4     thewhiskeydregs.com/wp-content/themes/widescre...   bad
# ...                                                 ...   ...
# 9995  paypal.com.us-cgi-bin-webscr-cmd.login.5885d80...   bad
# 9996  service.confirms.paypal.cmd.cgi-bins.2466sd4f3...   bad
# 9997  www.paypal.com-ca.cgi-bin.webscr.cmdflowsessio...   bad
# 9998  ns0.allnorilsk.ru/images/dk/fileadmin/dessing/...   bad
# 9999  abiraj.com.np/Paypal_Virefication/978288948cb2...   bad
#
# [10000 rows x 2 columns]
